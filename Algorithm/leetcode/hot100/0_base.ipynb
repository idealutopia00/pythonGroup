# %% [markdown]
# # base functions

# %%
from collections import defaultdict
from typing import List

# %%
strs = ["eat", "tea", "tan", "ate", "nat", "bat"]
groups = defaultdict(list)
for word in strs:
    key = tuple(sorted(word)) # 将单词转换为元组，并排序
    groups[key].append(word)
print(groups)
newkey = list(groups.keys())
print(newkey)
newvalue = list(groups.values())
print(newvalue)
# Out:
# defaultdict(<class 'list'>, {('a', 'e', 't'): ['eat', 'tea', 'ate'], ('a', 'n', 't'): ['tan', 'nat'], ('a', 'b', 't'): ['bat']})
# [('a', 'e', 't'), ('a', 'n', 't'), ('a', 'b', 't')]
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]

# %%
nums = [100, 4, 200, 1, 3, 2]
sortNums = sorted(list(set(nums)))
print(sortNums)
# Out:
# [1, 2, 3, 4, 100, 200]
